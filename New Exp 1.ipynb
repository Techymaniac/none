# %%
import pandas as pd
import numpy as np
from pgmpy.models import BayesianNetwork, DiscreteBayesianNetwork
from pgmpy.factors.discrete import TabularCPD
from pgmpy.inference import VariableElimination

# %%
# %pip install pgmpy
# Out:
# Requirement already satisfied: pgmpy in c:\users\shubh\anaconda3\lib\site-packages (1.0.0)
# Requirement already satisfied: networkx in c:\users\shubh\anaconda3\lib\site-packages (from pgmpy) (3.4.2)
# Requirement already satisfied: numpy in c:\users\shubh\anaconda3\lib\site-packages (from pgmpy) (2.1.3)
# Requirement already satisfied: scipy in c:\users\shubh\anaconda3\lib\site-packages (from pgmpy) (1.15.3)
# Requirement already satisfied: scikit-learn in c:\users\shubh\anaconda3\lib\site-packages (from pgmpy) (1.6.1)
# Requirement already satisfied: pandas in c:\users\shubh\anaconda3\lib\site-packages (from pgmpy) (2.2.3)
# Requirement already satisfied: torch in c:\users\shubh\anaconda3\lib\site-packages (from pgmpy) (2.9.0)
# Requirement already satisfied: statsmodels in c:\users\shubh\anaconda3\lib\site-packages (from pgmpy) (0.14.4)
# Requirement already satisfied: tqdm in c:\users\shubh\anaconda3\lib\site-packages (from pgmpy) (4.67.1)
# Requirement already satisfied: joblib in c:\users\shubh\anaconda3\lib\site-packages (from pgmpy) (1.4.2)
# Requirement already satisfied: opt-einsum in c:\users\shubh\anaconda3\lib\site-packages (from pgmpy) (3.4.0)
# Requirement already satisfied: pyro-ppl in c:\users\shubh\anaconda3\lib\site-packages (from pgmpy) (1.9.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\shubh\anaconda3\lib\site-packages (from pandas->pgmpy) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\shubh\anaconda3\lib\site-packages (from pandas->pgmpy) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\shubh\anaconda3\lib\site-packages (from pandas->pgmpy) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\shubh\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas->pgmpy) (1.17.0)
# Requirement already satisfied: pyro-api>=0.1.1 in c:\users\shubh\anaconda3\lib\site-packages (from pyro-ppl->pgmpy) (0.1.2)
# Requirement already satisfied: filelock in c:\users\shubh\anaconda3\lib\site-packages (from torch->pgmpy) (3.17.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in c:\users\shubh\anaconda3\lib\site-packages (from torch->pgmpy) (4.12.2)
# Requirement already satisfied: sympy>=1.13.3 in c:\users\shubh\anaconda3\lib\site-packages (from torch->pgmpy) (1.13.3)
# Requirement already satisfied: jinja2 in c:\users\shubh\anaconda3\lib\site-packages (from torch->pgmpy) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in c:\users\shubh\anaconda3\lib\site-packages (from torch->pgmpy) (2025.3.2)
# Requirement already satisfied: setuptools in c:\users\shubh\anaconda3\lib\site-packages (from torch->pgmpy) (72.1.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\shubh\anaconda3\lib\site-packages (from sympy>=1.13.3->torch->pgmpy) (1.3.0)
# Requirement already satisfied: colorama in c:\users\shubh\anaconda3\lib\site-packages (from tqdm->pgmpy) (0.4.6)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\shubh\anaconda3\lib\site-packages (from jinja2->torch->pgmpy) (3.0.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\shubh\anaconda3\lib\site-packages (from scikit-learn->pgmpy) (3.5.0)
# Requirement already satisfied: patsy>=0.5.6 in c:\users\shubh\anaconda3\lib\site-packages (from statsmodels->pgmpy) (1.0.1)
# Requirement already satisfied: packaging>=21.3 in c:\users\shubh\anaconda3\lib\site-packages (from statsmodels->pgmpy) (24.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
model = DiscreteBayesianNetwork([('Prize', 'Host'), ('Choice', 'Host')])

# %%
cpd_prize = TabularCPD(variable='Prize', variable_card=3,
                       values=[[1/3], [1/3], [1/3]],
                       state_names={'Prize': [1, 2, 3]})

# %%
cpd_choice = TabularCPD(variable='Choice', variable_card=3,
                        values=[[1/3], [1/3], [1/3]],
                        state_names={'Choice': [1, 2, 3]})

# %%
host_values = np.zeros((3, 9))

# %%
host_doors = [1, 2, 3]
for i, prize in enumerate(host_doors):
    for j, choice in enumerate(host_doors):
        valid = [door for door in host_doors if door != prize and door != choice]
        for v in valid:
            host_values[v-1][3*i + j] = 1 / len(valid)

cpd_host = TabularCPD(variable='Host', variable_card=3,
                      values=host_values,
                      evidence=['Prize', 'Choice'],
                      evidence_card=[3, 3],
                      state_names={'Host': [1, 2, 3], 'Prize': [1, 2, 3], 'Choice': [1, 2, 3]})

# %%
model.add_cpds(cpd_prize, cpd_choice, cpd_host)
model.check_model()
# Out:
# True

# %%
inference = VariableElimination(model)

# %%
query_result = inference.query(variables=['Prize'],
                               evidence={'Choice': 1, 'Host': 3})

# %%
print("P(Prize | Choice=1, Host=3):")
print(query_result)
# Out:
# P(Prize | Choice=1, Host=3):
# +----------+--------------+
# | Prize    |   phi(Prize) |
# +==========+==============+
# | Prize(1) |       0.3333 |
# +----------+--------------+
# | Prize(2) |       0.6667 |
# +----------+--------------+
# | Prize(3) |       0.0000 |
# +----------+--------------+

# %%
print("\nBest strategy: switch to the door with highest probability.")
# Out:
# Best strategy: switch to the door with highest probability.

# %% [markdown]
# After the installation is complete, please run the code cell again.
